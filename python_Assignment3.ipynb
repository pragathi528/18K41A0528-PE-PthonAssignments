# %% [markdown]
# <a href="https://colab.research.google.com/github/pragathi528/18K41A0528-PE-PthonAssignments/blob/master/python_Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 1) Read mobile dataset using pandas, and preprocess it (fill null values).

# %%
d=pd.read_csv("/content/drive/My Drive/Pics/mobile-cleaned. csv")

# %%
d.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            1
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
d.isnull().sum().sum()
# Out:
# 10

# %%
d.describe()
# Out:
#          sim_type    aperture    gpu_rank      weight  stand_by_time  \
# count  109.000000  109.000000  109.000000  108.000000     106.000000
# mean     0.981651    7.733945   29.990826  154.121296     404.584906
# std      1.347025    3.201973   15.300385   22.360492     178.489582
# min      0.000000    0.000000    3.000000   97.000000     160.000000
# 25%      0.000000    8.000000   16.000000  139.500000     264.000000
# 50%      0.000000    8.000000   29.000000  152.000000     360.000000
# 75%      3.000000   10.000000   41.000000  169.000000     499.000000
# max      4.000000   14.000000   56.000000  234.000000    1093.000000
#
#        processor_frequency   thickness  flash_type  front_camera_resolution  \
# count           109.000000  109.000000  109.000000               109.000000
# mean              1.633394    8.330275    3.844037                 4.840550
# std               0.386773    1.173828    1.582159                 2.578122
# min               1.000000    5.100000    0.000000                 0.300000
# 25%               1.300000    7.600000    2.000000                 4.000000
# 50%               1.600000    8.100000    5.000000                 5.000000
# 75%               1.800000    8.900000    5.000000                 5.000000
# max               2.700000   11.600000    7.000000                16.000000
#
#        auto_focus  screen_size  frames_per_second          FM  \
# count  109.000000   109.000000         109.000000  109.000000
# mean     2.954128     5.211468          30.550459    2.559633
# std      0.416896     0.413187           6.431241    1.109147
# min      0.000000     4.000000          15.000000    0.000000
# 25%      3.000000     5.000000          30.000000    2.000000
# 50%      3.000000     5.200000          30.000000    3.000000
# 75%      3.000000     5.500000          30.000000    3.000000
# max      4.000000     6.800000          60.000000    5.000000
#
#        no_of_reviews_in_gsmarena_in_week          os  phone_height  \
# count                         107.000000  109.000000    108.000000
# mean                          109.084112    0.183486    146.803704
# std                           209.603405    0.595743     12.194720
# min                             0.000000    0.000000     69.000000
# 25%                             0.000000    0.000000    142.000000
# 50%                            22.000000    0.000000    147.250000
# 75%                           124.000000    0.000000    152.525000
# max                          1304.000000    3.000000    186.600000
#
#        screen_protection    sim_size         price   talk_time  \
# count         109.000000  109.000000    109.000000  108.000000
# mean           14.623853    6.211009  19373.211009   19.898148
# std             8.783179    3.567013  14039.197220    9.300728
# min             0.000000    0.000000   3870.000000    6.000000
# 25%             5.000000    3.000000   8999.000000   13.000000
# 50%            16.000000    5.000000  14614.000000   19.000000
# 75%            25.000000    9.000000  24999.000000   24.000000
# max            26.000000   12.000000  64500.000000   48.000000
#
#        video_resolution  display_resolution  removable_battery  display_type  \
# count        108.000000          109.000000         109.000000    109.000000
# mean        1310.888889            7.000000           1.926606      3.422018
# std          539.035576            4.141032           1.184048      3.124851
# min          216.000000            0.000000           0.000000      0.000000
# 25%         1080.000000            4.000000           1.000000      2.000000
# 50%         1080.000000            9.000000           1.000000      2.000000
# 75%         2160.000000            9.000000           3.000000      5.000000
# max         2160.000000           18.000000           5.000000     12.000000
#
#        primary_camera_resolution  battery_type  ram_memory  internal_memory  \
# count                 108.000000    109.000000  109.000000       109.000000
# mean                   12.588333      1.798165    6.954128         3.605505
# std                     4.071291      1.120349   48.831036         1.962700
# min                     5.000000      0.000000    1.000000         0.000000
# 25%                     8.000000      1.000000    2.000000         2.000000
# 50%                    13.000000      2.000000    2.000000         2.000000
# 75%                    13.000000      2.000000    3.000000         4.000000
# max                    23.000000      6.000000  512.000000         7.000000
#
#        brand_rank  no_of_cores  micro_sd_slot  screen_pixel_density  \
# count  109.000000   109.000000     109.000000            109.000000
# mean     8.155963     4.972477       3.541284             14.743119
# std      7.062124     2.187755       1.437153              7.963346
# min      1.000000     0.000000       0.000000              0.000000
# 25%      3.000000     4.000000       3.000000              9.000000
# 50%      6.000000     6.000000       4.000000             14.000000
# 75%     11.000000     6.000000       4.000000             20.000000
# max     30.000000    12.000000       6.000000             34.000000
#
#        water_proof_rate  phone_width  expandable_memory     version  \
# count        109.000000   109.000000         109.000000  109.000000
# mean           4.908257    74.261468         104.513761    6.082569
# std            1.708049     7.908726         275.799767    2.546342
# min            0.000000    58.600000           0.000000    0.000000
# 25%            3.000000    70.900000           0.000000    5.000000
# 50%            6.000000    73.700000          32.000000    6.000000
# 75%            6.000000    76.700000         128.000000    6.000000
# max            7.000000   136.500000        2048.000000   14.000000
#
#          usb_type  battery_capacity  processor_rank    is_liked
# count  109.000000        109.000000      109.000000  109.000000
# mean     4.376147       2841.779817       50.788991    0.844037
# std      3.146983        655.003963       49.496366    0.364496
# min      0.000000       1560.000000        1.000000    0.000000
# 25%      3.000000       2470.000000       12.000000    1.000000
# 50%      3.000000       2900.000000       21.000000    1.000000
# 75%      4.000000       3100.000000       92.000000    1.000000
# max     14.000000       5000.000000      166.000000    1.000000

# %%
d['weight']=d['weight'].fillna(d['weight'].mean())
d['stand_by_time']=d['stand_by_time'].fillna(d['stand_by_time'].mean())
d['no_of_reviews_in_gsmarena_in_week']=d['no_of_reviews_in_gsmarena_in_week'].fillna(d['no_of_reviews_in_gsmarena_in_week'].mean())
d['phone_height']=d['phone_height'].fillna(d['phone_height'].mean())
d['talk_time']=d['talk_time'].fillna(d['talk_time'].mean())
d['video_resolution']=d['video_resolution'].fillna(d['video_resolution'].mean())
d['primary_camera_resolution']=d['primary_camera_resolution'].fillna(d['primary_camera_resolution'].mean())

# %%
d.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            0
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
d.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# 2) Draw correlation graph for mobile price with all attributes.

# %%
import matplotlib.pyplot as plt
p=list(d["price"])
l=list(d.columns)
for n in l :
   c=list(d[n])
   plt.xlabel(n)
   plt.ylabel("price")
   plt.plot(c,p,label=n)
   plt.scatter(c,p)
   plt.legend()
   plt.show()

# %% [markdown]
# 3)Compute outer product of 2 vectors.

# %%
p=[[1,0],[0,1]]
q=[[1,2],[3,4]]
np.outer(p,q)
# Out:
# array([[1, 2, 3, 4],
#        [0, 0, 0, 0],
#        [0, 0, 0, 0],
#        [1, 2, 3, 4]])

# %% [markdown]
# 4) Write a NumPy program to compute the condition number of a given matrix.

# %%
import numpy as np
matrix = np.array([[1, 2], [3, 4]])
print("Original matrix: ")
print(matrix) 
print("Condition number of the said matrix: ")
result = np.linalg.cond(matrix)
print(result)
# Out:
# Original matrix:
# [[1 2]
#  [3 4]]
# Condition number of the said matrix:
# 14.933034373659268

# %% [markdown]
# 5) write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
import numpy as np
d=np.array([[10,8,5],[4,4,9],[3,0,5]])
print("matrix=\n",d)
p=np.trace(d)
print("trace=",p)
# Out:
# matrix=
#  [[10  8  5]
#  [ 4  4  9]
#  [ 3  0  5]]
# trace= 19
